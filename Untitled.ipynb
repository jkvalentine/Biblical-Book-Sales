# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %%
df = pd.read_csv('book_sales_df.csv')

# %%
df.drop(df['book'] == 'The_Bible').reset_index(drop=True, inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=71, step=1)

# %%
plt.scatter(df['nmf_similarity'], df['avg_sales_per_year'])

# %%
df.drop(['first_published', 'approximate_sales','text_file'], axis=1)
# Out:
#                                                  book  avg_sales_per_year  \
# 0                                           The_Bible        1.231527e+07
# 1                                         Don_Quixote        1.234568e+06
# 2                                A_Tale_of_Two_Cities        1.265823e+06
# 3                          The_Fellowship_of_the_Ring        2.460317e+06
# 4                                      The_Two_Towers        2.380952e+06
# 5                                       The_Alchemist        5.172414e+06
# 6                                          The_Hobbit        1.750000e+06
# 7                              The_Return_of_the_King        2.258065e+06
# 8             Harry_Potter_and_the_Philosophers_Stone        5.350000e+03
# 9                            And_Then_There_Were_None        1.282051e+06
# 10                       The_Dream_of_the_Red_Chamber        3.802281e+05
# 11                                Alice_in_Wonderland        6.578947e+05
# ...
